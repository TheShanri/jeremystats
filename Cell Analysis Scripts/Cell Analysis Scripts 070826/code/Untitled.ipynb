# %%
from kilosort.io import load_ops
from kilosort.data_tools import (
    mean_waveform, cluster_templates, get_good_cluster, get_cluster_spikes, get_spike_waveforms, get_refractory, get_labels, get_templates)

import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import gaussian_filter1d
from scipy.signal import find_peaks
from pathlib import Path

# %%
def compute_isi (spike_times_millisec)
    return np.diff(np.sort(spike_times_millisec))

def cv2 (isi)
    return
